# %%
import nltk
import pandas as pd
from nltk.tag import pos_tag
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from nltk.stem import WordNetLemmatizer

# %%
# Natural Language Processing on Not-So-Natural-Language
# MosesTokenizer gets rid of a lot of symbols
# bigrams? trigrams?
# bigrams based on parts of speech
# Dashlane and other password sites are WRONG
# --Create a new one
# --https://nakedsecurity.sophos.com/2015/03/02/why-you-cant-trust-password-strength-meters/
# Google n-gram and unigram lists

# %%
words = []

with open('pass.txt') as f:
    for i in f.readlines():
        words.append(i.strip())

# %%
wordslong = []

with open('pass_long.txt') as f:
    for i in f.readlines():
        wordslong.append(i.strip())

# %%
len(wordslong)
# Out:
# 11297

# %%
words
# Out:
# ['!pass1234*',
#  '!password',
#  '!password!',
#  '!password09',
#  '!password1',
#  '!password@',
#  '$passw0rd',
#  '$password',
#  '$password1',
#  '***password',
#  '.password',
#  '.password1',
#  '007password',
#  '00pass00',
#  '05password',
#  '06password',
#  '07password',
#  '0password',
#  '0password0',
#  '100password',
#  '10password',
#  '11pass',
#  '11password',
#  '123456pass',
#  '1234pass',
#  '123@password',
#  '123pass',
#  '123pass123',
#  '123pass2me',
#  '123pass456',
#  '123passs',
#  '123password',
#  '123passy',
#  '12pass',
#  '12pass2',
#  '12password',
#  '1313pass',
#  '1337pass',
#  '13password',
#  '14password',
#  '15password',
#  '16password',
#  '17password',
#  '18password',
#  '19password',
#  '1apassword',
#  '1pass1t',
#  '1pass2word3',
#  '1passat',
#  '1passcode',
#  '1passion',
#  '1password',
#  '1password1',
#  '1password2',
#  '1passwort',
#  '1wordpass1',
#  '20password',
#  '22password',
#  '22wordpass',
#  '23password',
# ...

# %%
wordslong
# Out:
# ['!pass1234',
#  '!password2',
#  '$password12',
#  '$password7',
#  '0001pass',
#  '0013pass',
#  '001pass',
#  '007pass',
#  '00pass',
#  '00password',
#  '0101pass',
#  '0103pass',
#  '01pass',
#  '01password',
#  '0202pass',
#  '02password',
#  '0314pass',
#  '04pass',
#  '0504pass',
#  '0608pass',
#  '0814pass',
#  '0882pass',
#  '08password',
#  '0923pass',
#  '09password',
#  '0copass',
#  '0pass0',
#  '0pass123',
#  '0pass2',
#  '0password1',
#  '0passwords',
#  '0zpass',
#  '1000pass',
#  '1001pass',
#  '1002pass',
#  '1004pass',
#  '1005pass',
#  '1008pass',
#  '100pass',
#  '100passi',
#  '100passwords',
#  '1010pass',
#  '1011pass',
#  '1012pass',
#  '1017pass',
#  '1018pass',
#  '1019pass',
#  '1021pass',
#  '1022pass',
#  '1023pass',
#  '1024pass',
#  '1025pass',
#  '1026pass',
#  '1027pass',
#  '1029pass',
#  '102password',
#  '1030pass',
#  '1041pass',
#  '1044pass',
#  '1052pass',
#  '1058pass',
#  '108pass',
#  '1092pass',
#  '10pass',
#  '1103pass',
#  '1106pass',
# ...

# %%
wordstr = " ".join(words)

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c6968b8e0d1c> in <module>()
#       1 from nltk.tokenize import TreebankWordTokenizer
#       2 tokenizer = TreebankWordTokenizer()
# ----> 3 tokenizer.tokenize()
#
# TypeError: tokenize() takes exactly 2 arguments (1 given)

# %%
from nltk.tokenize import word_tokenize
tokenizer = word_tokenize(wordstr)
tokenizer

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(wordstr)

# %%
from nltk.tokenize.moses import MosesTokenizer

# %%
tokenizer = MosesTokenizer()
tokenized_text = tokenizer.tokenize(wordstr, agressive_dash_splits=True)
tokenized_text

# %%
from sklearn.feature_extraction.text import CountVectorizer

# text = ['That is should come to this!', 'This above all: to thine own self be true.', 'Something is rotten in the state of Denmark.']

#CountVectorizer is a class; so `vectorizer` below represents an instance of that object.
vectorizer = CountVectorizer(ngram_range=(1,2), analyzer='word')

# call `fit` to build the vocabulary
vectorizer.fit(tokenized_text)

# then, use `get_feature_names` to return the tokens
print(vectorizer.get_feature_names())

# finally, call `transform` to convert text to a bag of words
x = vectorizer.transform(tokenized_text)

# %%
print('Sparse Matrix')
# A compressed version; the "sparse" matrix.
print(type(x))
print(x)

print ('Matrix')
x_back = x.toarray()
print(type(x_back))
print(x_back)

# %%
ft = pd.DataFrame(x_back, columns=vectorizer.get_feature_names())

# %%
ft.sum().sort_values(ascending = False)

# %% [markdown]
# ## Stemming

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
file_arg = "/test/blah/haha/sup.py"
name = file_arg.split('/')[-1]
fpath = "/".join(file_arg.split('/')[:-1])

# %%
name
# Out:
# 'sup.py'

# %%
fpath
# Out:
# '/test/blah/haha'

# %%
fpath + '/' + name.split('.')[-1] + '_out.txt'
# Out:
# '/test/blah/haha/py_out.txt'
