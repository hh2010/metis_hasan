# %% [markdown]
# <h1>Exercise 2.4 - Hasan Haq</h1>
#
# <b>Using the variable totalwgt_lb, investigate whether first babies are lighter or heavier than others. Compute Cohen’s d to quantify the difference between the groups. How does it compare to the difference in pregnancy length?</b>

# %%
# Import all the modules we use in the textbook exercises
import thinkstats2
import thinkplot
import nsfg
import pandas as pd
import numpy as np
import math

# %%
# Create the Series we will be using, 'totalwgt_lb', from the raw data
preg = nsfg.ReadFemPreg()
preg['totalwgt_lb'] = df.birthwgt_lb + df.birthwgt_oz / 16.0
live = preg[preg.outcome == 1]

# %%
# Define function for CohenEffectSize
def CohenEffectSize(group1, group2):
    diff = group1.mean() - group2.mean()
    var1 = group1.var()
    var2 = group2.var()
    n1, n2 = len(group1), len(group2)
    pooled_var = (n1 * var1 + n2 * var2) / (n1 + n2)
    d = diff / math.sqrt(pooled_var)
    return d

# %%
# Plot the totalwgt_lb data
hist1 = thinkstats2.Hist(live.totalwgt_lb, label='totalwgt_lb')
thinkplot.Hist(hist1)
thinkplot.Show(xlabel='total pounds', ylabel='frequency')

# %%
firsts = live[live.birthord == 1]
others = live[live.birthord != 1]
first_hist = thinkstats2.Hist(firsts.totalwgt_lb, label="Firsts")
other_hist = thinkstats2.Hist(others.totalwgt_lb, label="Others")

# %%
# Histogram not the best visualization for a continuous dataset
#   But it is all we have learned in this chapter so far
width = 0.45
thinkplot.PrePlot(2)
thinkplot.Hist(first_hist, align='right', width=width)
thinkplot.Hist(other_hist, align='left', width=width)
thinkplot.Show(xlabel='total weight (lbs)', ylabel='frequency')

# %%
# Calculate Cohen Effect Size
CohenEffectSize(firsts.totalwgt_lb, others.totalwgt_lb)
# Out:
# -0.088672927072602

# %% [markdown]
# <h1><font color="red">Solution to Exercise 2.4</font></h1>
#
# <h3><font color="blue">Cohen Effect Size:
# d = -0.089</font></h3>
#
# <b>Based on the small <i>Cohen's 'd'</i>, the effect on birth weight from being first in the birth order is not very strong.  This is similar to the weak relationship between pregnancy length and birth order.
#
# However, in this case, the 'd' value is negative.  This means that if there is an effect on birth weight, it is likely such that the first-born is actually likely to be <i>smaller</i> than the others.</b>
