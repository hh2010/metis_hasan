# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xs = []
ys = []

for x in range(30,5000):
    lst = [1 for x in range(x)]
    xs.append(len(lst))
    a = %timeit -n10 -o lst.pop(0)
    ys.append(sum(a.all_runs)/len(a.all_runs))
# Out:
# 10 loops, best of 3: 709 ns per loop
# 10 loops, best of 3: 353 ns per loop
# 10 loops, best of 3: 313 ns per loop
# The slowest run took 34.42 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10 loops, best of 3: 567 ns per loop
# 10 loops, best of 3: 332 ns per loop
# 10 loops, best of 3: 318 ns per loop
# 10 loops, best of 3: 339 ns per loop
# 10 loops, best of 3: 324 ns per loop
# The slowest run took 11.69 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10 loops, best of 3: 322 ns per loop
# 10 loops, best of 3: 327 ns per loop
# 10 loops, best of 3: 329 ns per loop
# 10 loops, best of 3: 660 ns per loop
# 10 loops, best of 3: 576 ns per loop
# 10 loops, best of 3: 388 ns per loop
# 10 loops, best of 3: 588 ns per loop
# 10 loops, best of 3: 281 ns per loop
# 10 loops, best of 3: 619 ns per loop
# 10 loops, best of 3: 678 ns per loop
# 10 loops, best of 3: 270 ns per loop
# ...

# %%
plt.plot(xs, ys);
