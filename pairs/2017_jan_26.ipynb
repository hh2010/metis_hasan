# %% [markdown]
# We'll use `statsmodels` to fit some (Ordinary Least Squares) linear models using random data.
# First make a response `y` of 200 random numbers. Then generate 20 random features in an `X`
# to predict with. Fit a linear model using both the 'Famous Equation' and the python built-ins.
# Check the `summary()` output of the results from the python built-ins. Do you have any features
# with `P>|t|` less than 0.05? (Repeat the process until you have at least one.)
# Check out the model's `R-squared` and `Adj. R-squared`. Repeat the feature generation and model
# fitting process with 40, 60, 80, and 100 features. What happens with `R-squared` and `Adj. R-squared`?
# If you have time, automate this experimental procedure and make a plot
# of `R-squared` and `Adj. R-squared` against number of features for one
# to one hundred features.

# %%
import statsmodels
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
xs = map(lambda x: "X" + str(x), range(1, 21))

# %%
np.random.seed(0)
df_x = pd.DataFrame(np.random.rand(200,20), columns=xs)
df_y = pd.DataFrame(np.random.rand(200,1), columns=['Y'])
df = df_y.join(df_x)
df_xs = df.drop(['Y'], 1)

# %%
pd.options.display.max_rows = 20
df.corr()
# Out:
#             Y        X1        X2        X3        X4        X5        X6  \
# Y    1.000000  0.029695 -0.003284  0.014470 -0.015712  0.012721  0.061886
# X1   0.029695  1.000000  0.062205  0.028148 -0.013822  0.059583  0.037936
# X2  -0.003284  0.062205  1.000000 -0.025533 -0.075947  0.094135  0.015830
# X3   0.014470  0.028148 -0.025533  1.000000  0.054588  0.006770 -0.033201
# X4  -0.015712 -0.013822 -0.075947  0.054588  1.000000  0.084550  0.164151
# X5   0.012721  0.059583  0.094135  0.006770  0.084550  1.000000  0.101695
# X6   0.061886  0.037936  0.015830 -0.033201  0.164151  0.101695  1.000000
# X7  -0.067190 -0.042230 -0.093409  0.098152  0.053012 -0.097316  0.011095
# X8  -0.130483 -0.109706 -0.013345 -0.022209  0.011746 -0.126001 -0.104186
# X9  -0.066262 -0.082266  0.022155  0.087798  0.070294  0.072534  0.055921
# ..        ...       ...       ...       ...       ...       ...       ...
# X11  0.017794  0.005369 -0.053553  0.093097 -0.116893 -0.122200 -0.029052
# ...

# %%
# Need to include intercept!! Why?

lsm = sm.OLS(df_y,df_x)
fit4 = lsm.fit()
fit4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     29.39
# Date:                Thu, 26 Jan 2017   Prob (F-statistic):           3.21e-46
# Time:                        10:24:12   Log-Likelihood:                -23.790
# No. Observations:                 200   AIC:                             87.58
# Df Residuals:                     180   BIC:                             153.5
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X1             0.0400      0.074      0.543      0.587        -0.105     0.185
# ...
