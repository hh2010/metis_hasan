# %%
import os
import pandas as pd
import numpy as np
import string
import re
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import cross_val_score
from sklearn.learning_curve import learning_curve
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from collections import Counter
from tqdm import tqdm

# %matplotlib inline

# %%
def grab(folder):
    tot = []
    inp = './data/review_polarity/txt_sentoken/' + folder + '/'
    for filename in tqdm(os.listdir(inp)):
        with open(inp + filename, 'r', errors='ignore') as f:
            words = "".join(f.readlines())
            words_clean = re.sub(r'[^\w\s]', '', words)
            tot += words_clean.split()
    return tot

# %%
pos = grab('pos')
# Out:
# 100%|██████████| 1001/1001 [00:00<00:00, 2766.74it/s]

# %%
neg = grab('neg')
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 3137.95it/s]

# %%
x = grab('pos') + grab('neg')
y_pos = [1 for x in grab('pos')]
y_neg = [0 for x in grab('neg')]
y = y_pos + y_neg
# Out:
# ...
# 100%|██████████| 1000/1000 [00:00<00:00, 2764.87it/s]

# %%
# Out:
# [('the', 41361),
#  ('a', 20132),
#  ('and', 19776),
#  ('of', 18550),
#  ('to', 16435),
#  ('is', 14048),
#  ('in', 11611),
#  ('that', 7752),
#  ('as', 6463),
#  ('it', 6416),
#  ('with', 5842),
#  ('his', 5580),
#  ('for', 5246),
#  ('film', 4864),
#  ('this', 4639),
#  ('but', 4471),
#  ('he', 4331),
#  ('are', 3711),
#  ('on', 3657),
#  ('i', 3461),
#  ('by', 3457),
#  ('its', 3169),
#  ('an', 3048),
#  ('be', 2989),
#  ('who', 2908),
#  ('one', 2904),
#  ('not', 2897),
#  ('from', 2726),
#  ('has', 2562),
#  ('at', 2485),
#  ('was', 2476),
#  ('her', 2451),
#  ('movie', 2389),
#  ('have', 2239),
#  ('you', 2212),
#  ('they', 2116),
#  ('all', 2111),
#  ('more', 1838),
#  ('which', 1741),
#  ('like', 1718),
#  ('about', 1718),
#  ('out', 1701),
#  ('their', 1690),
#  ('so', 1672),
#  ('when', 1671),
#  ('what', 1603),
#  ('up', 1528),
#  ('him', 1476),
#  ('or', 1472),
#  ('some', 1463),
#  ('she', 1441),
#  ('most', 1387),
#  ('into', 1360),
#  ('just', 1339),
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=4444)

# %%
X_train_ct = sorted(Counter(X_train).items(), key=lambda x: x[1], reverse=True)

# %%
X_test_ct = sorted(Counter(X_test).items(), key=lambda x: x[1], reverse=True)

# %%
y_train_ct = sorted(Counter(y_train).items(), key=lambda x: x[1], reverse=True)

# %%
y_test_ct = sorted(Counter(y_test).items(), key=lambda x: x[1], reverse=True)

# %%
X_train_ct
# Out:
# [('the', 53297),
#  ('a', 26595),
#  ('and', 24664),
#  ('of', 23723),
#  ('to', 22379),
#  ('is', 17755),
#  ('in', 15114),
#  ('that', 10580),
#  ('it', 8591),
#  ('as', 7967),
#  ('with', 7564),
#  ('for', 6932),
#  ('his', 6676),
#  ('this', 6649),
#  ('film', 6271),
#  ('but', 6030),
#  ('he', 5328),
#  ('i', 5255),
#  ('on', 5028),
#  ('are', 4897),
#  ('by', 4326),
#  ('be', 4261),
#  ('its', 4247),
#  ('an', 4014),
#  ('not', 3901),
#  ('one', 3846),
#  ('movie', 3814),
#  ('who', 3760),
#  ('from', 3527),
#  ('was', 3512),
#  ('have', 3484),
#  ('at', 3467),
#  ('has', 3318),
#  ('her', 3146),
#  ('you', 3088),
#  ('they', 3054),
#  ('all', 2957),
#  ('so', 2539),
#  ('like', 2497),
#  ('about', 2436),
#  ('out', 2419),
#  ('more', 2370),
#  ('when', 2285),
#  ('which', 2204),
#  ('their', 2177),
#  ('up', 2175),
#  ('what', 2170),
#  ('or', 2155),
#  ('some', 2110),
#  ('just', 2046),
#  ('if', 1968),
#  ('there', 1907),
#  ('she', 1865),
#  ('him', 1839),
# ...

# %%
tot_words = sum([i[1] for i in X_train_ct])

# %%
new_ct = [(x, np.log(y / (tot_words - y))) for x, y in X_train_ct]

# %%
# Look up "logsum"
# Look up "laploss smoothing"
# Out:
# [('the', -2.7718003747254181),
#  ('a', -3.4978136296303015),
#  ('and', -3.5753871161042019),
#  ('of', -3.6153546471111815),
#  ('to', -3.6751999164627147),
#  ('is', -3.9118788102958337),
#  ('in', -4.0758954580924494),
#  ('that', -4.4376314504756857),
#  ('it', -4.6481021169186247),
#  ('as', -4.7242048263844429),
#  ('with', -4.7765616552863968),
#  ('for', -4.8645171193636543),
#  ('his', -4.9024313815824909),
#  ('this', -4.9065139628730554),
#  ('film', -4.9654651047475831),
#  ('but', -5.0049219336868411),
#  ('he', -5.1294732730486219),
#  ('i', -5.1433503053641276),
#  ('on', -5.1877601752077167),
#  ('are', -5.2143051817657895),
#  ('by', -5.3389185322491226),
#  ('be', -5.3541301206414866),
#  ('its', -5.3574366799979956),
#  ('an', -5.4141198117801217),
#  ('not', -5.4428004894682998),
#  ('one', -5.4570607820181172),
#  ('movie', -5.4654514165508594),
#  ('who', -5.4797708605142379),
#  ('from', -5.5440005578622928),
#  ('was', -5.5482791656827048),
# ...
